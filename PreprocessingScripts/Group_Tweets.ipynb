# %% [markdown]
# ## Imports

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
import os
import pandas as pd
import numpy as np
import ast
import re

# %% [markdown]
# ## Download Dataset

# %%
# Download latest version
path = kagglehub.dataset_download("ahmedshahriarsakib/top-1000-twitter-celebrity-tweets-embeddings")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/ahmedshahriarsakib/top-1000-twitter-celebrity-tweets-embeddings?dataset_version_number=3...
# 100%|██████████| 171M/171M [00:29<00:00, 6.02MB/s]
# Extracting files...
# Path to dataset files: C:\Users\tejas\.cache\kagglehub\datasets\ahmedshahriarsakib\top-1000-twitter-celebrity-tweets-embeddings\versions\3

# %%
BASE_PATH = os.path.join(os.path.join(path, "twitter-celebrity-tweets-data"), "twitter-celebrity-tweets-data")
# List to store dataframes from each celebrity
all_celebrity_data = []

# Iterate through each file in the specified directory
for filename in os.listdir(BASE_PATH):
    if filename.endswith('.csv'):
        celebrity_name = os.path.splitext(filename)[0]
        
        file_path = os.path.join(BASE_PATH, filename)
        try:
            # Read the CSV file
            df = pd.read_csv(file_path)
            df.head()
    
            # Determine the number of rows to sample
            num_rows = len(df)
            sample_size = min(num_rows, 50)

            if sample_size > 0:
                # Randomly sample 'sample_size' rows
                sampled_df = df.sample(n=sample_size, random_state=42) # Using random_state for reproducibility
                sampled_df['name'] = celebrity_name
                all_celebrity_data.append(sampled_df)
                
        except pd.errors.EmptyDataError:
            print(f"Warning: {filename} is empty and was skipped.")
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# %%
# Concatenate all sampled dataframes into a single dataframe
if all_celebrity_data:
    final_df = pd.concat(all_celebrity_data, ignore_index=True)
    print("\n--- Data Extraction Complete ---")
    print(f"Final DataFrame shape: {final_df.shape}")
    print("\nFirst 5 rows of the combined DataFrame:")
    print(final_df.head())
else:
    print("\nNo CSV files found or processed. Final DataFrame is empty.")
# Out:
# --- Data Extraction Complete ---
# Final DataFrame shape: (45031, 4)
#
# First 5 rows of the combined DataFrame:
#             twitter_id                       date  \
# 0  1265675160813780996  2020-05-27 16:04:08+00:00
# 1  1352116023261097987  2021-01-21 04:49:15+00:00
# 2  1305913958898053121  2020-09-15 16:58:45+00:00
# 3  1515766356548984835  2022-04-17 18:57:15+00:00
# 4  1166752233305886721  2019-08-28 16:39:44+00:00
#
#                                                tweet    name
# 0  b'RT @OSDONOSDABOLA: O Craque @10neto j\xc3\xa...  10neto
# 1  b'@plihalespn Vc t\xc3\xa1 certo \xf0\x9f\x97\...  10neto
# 2  b'Parab\xc3\xa9ns ao @Gremio pelos 117 anos de...  10neto
# 3  b'Inacredit\xc3\xa1vel o p\xc3\xaanalti que ma...  10neto
# 4  b'RT @OSDONOSDABOLA: A\xc3\xad galera, vamos v...  10neto

# %%
final_df['name'].unique()
# Out:
# array(['10neto', '10Ronaldinho', '143redangel', '1LoganHenderson',
#        '1victorvaldes', '21LVA', '3gerardpique', '4everBrandy', '50cent',
#        '5SOS', '6BillionPeople', '7sainaljassmi', 'aarbeloa17',
#        'aaronpaul_8', 'ABdeVilliers17', 'abdulrahman', 'ActorLeeMinHo',
#        'ActuallyNPH', 'acunilicali', 'AdalRamones', 'adamlambert',
#        'adamlevine', 'AdamSchefter', 'AdelAliBinAli', 'Adela_Micha',
#        'Adele', 'AdnanAlarour', 'agnezmo', 'aguerosergiokun', 'ahickmann',
#        'ahmethc', 'AHMTKURAL', 'ajaydevgn', 'Akon', 'akshaykumar',
#        'AlbertoCiurana', 'AlejandroSanz', 'alexoficial', 'AlfredoFlores',
#        'aliaa08', 'aliciakeys', 'alinebarros', 'AllRiseSilver',
#        'alo_oficial', 'AlvaroMorata', 'Alwaleed_Talal', 'alyankovic',
#        'Alyssa_Milano', 'amandabynes', 'amrdiab', 'amrkhaled', 'amrwaked',
#        'amyschumer', 'Anahi', 'anakarylle', 'ANAMARIABRAGA',
#        'anandmahindra', 'andersoncooper', 'AndreaLegarreta',
#        'AndreaSernaTV', 'andreolifelipe', 'andrescepeda',
#        'andresiniesta8', 'andy_murray', 'angelicaksy', 'angelicavale',
#        'Angelluisr', 'Anggun_Cipta', 'AnnaKendrick47', 'annecurtissmith',
#        'AnselElgort', 'antanddec', 'AnupamPkher', 'AnushkaSharma',
#        'aplusk', 'apriliokevin', 'aristeguicnn', 'ariyoshihiroiki',
#        'arrahman', 'AshBenzo', 'ashleesimpson', 'ashleytisdale',
#        'Ashton5SOS', 'Asli_Jacqueline', 'assihallani', 'atademirer',
#        'AudrinaPatridge', 'AustinMahone', 'AvrilLavigne', 'AxelOficial',
#        'ayseozyilmazel', 'ayushmannk', 'azizansari', 'BarackObama',
#        'battalalgoos', 'bclsinclair', 'BDUTT', 'BeingSalmanKhan',
#        'belalfadl', 'belindapop', 'bellathorne', 'Bellaudyaa', 'Benzema',
#        'bep', 'bepe20s', 'bernardokath', 'BethanyMota', 'Beyonce',
#        'bhogleharsha', 'BigSean', 'bigtimerush', 'BillCosby', 'BillGates',
#        'billmaher', 'BillNye', 'BillSimmons', 'bipsluvurself',
#        'BIRDMAN5STAR', 'biz', 'blakeshelton', 'BoAkwon', 'bobsaget',
#        'bomanirani', 'bonnovanderputt', 'booba', 'Bourdain',
#        'BradPaisley', 'bridgitmendler', 'britneyspears', 'brookeburke',
#        'brozoxmiswebs', 'BruMarquezine', 'brunogagliasso', 'BRUNOIERULLO',
#        'BrunoMars', 'BSchweinsteiger', 'Buenafuente', 'BustaRhymes',
#        'cadieckmann', 'CaioCastro', 'Caitlyn_Jenner', 'cala', 'Calum5SOS',
#        'CalvinHarris', 'camerondallas', 'Caradelevingne', 'Carles5puyol',
#        'carlosbaute', 'CarlosLoret', 'carlosvives', 'carlyraejepsen',
#        'carmeloanthony', 'CAROLE_SAMAHA', 'carrieunderwood',
#        'carterreynolds', 'Caspar_Lee', 'ceracoat', 'cerati',
#        'cesc4official', 'CH14_', 'channingtatum', 'charliesheen',
#        'Charlottegshore', 'CHAYANNEMUSIC', 'chelseahandler', 'cher',
#        'CherLloyd', 'CherylOfficial', 'ChespiritoRGB', 'chetan_bhagat',
#        'chinasuarez', 'ChinoyNacho', 'chrisbrown', 'chriscolfer',
#        'ChrisEvans', 'ChrisMoyles', 'chrisrock', 'ciara', 'ClaudiaLeitte',
#        'CMPunk', 'CMYLMZ', 'CodySimpson', 'coldplay', 'common',
#        'ConanOBrien', 'corbuzier', 'cortezrafa', 'CP3', 'CraigyFerg',
#        'Cristiano', 'cuervotinelli', 'cuneytozdemir', 'Cyrilhanouna',
#        'daddy_yankee', 'danawhite', 'DaneCook', 'DaniAlvesD2',
#        'DaniellePeazer', 'danieltosh', 'DaniloGentili', 'danimartinezweb',
#        'danisuzuki', 'dannapaola', 'DannyDeVito', 'DaRealAmberRose',
#        'davidbisbal', 'davidguetta', 'DavidHenrie', 'DavidKWilliams',
#        'DavidLuiz_4', 'DavidSpade', 'DAVID_LYNCH', 'Dbolina', 'ddlovato',
#        'deadmau5', 'DebbouzeJamel', 'DebbyRyan', 'dedesecco',
#        'DeepakChopra', 'deepikapadukone', 'DemetAkalin',
#        'DENISE_RICHARDS', 'DennyCagur', 'depechemode', 'desta80s',
#        'dhikacungkring', 'DiegoForlan7', 'diegotorres', 'djkhaled',
#        'DjKingAssassin', 'DjokerNole', 'DJPaulyD', 'DollyParton',
#        'donghae861015', 'DONOMAR', 'Drake', 'DrakeBell',
#        'drangelocarbone', 'drdre', 'drdrew', 'drose', 'DrOz',
#        'Dr_alqarnee', 'DulceMaria', 'dumbassgenius', 'DwightHoward',
#        'DwyaneWade', 'dylanobrien', 'Dynamomagician', 'D_DeGea',
#        'D_Ospina1', 'eddieizzard', 'edsheeran', 'ElBaradei',
#        'EleanorJCalder', 'elissakh', 'elliegoulding', 'elmorenomichael',
#        'elonmusk', 'EmilyOsment', 'Eminem', 'emreaydin', 'ErikaDLV',
#        'ErinAndrews', 'eseryenenler', 'esmuellert_', 'EspinozaOficial',
#        'EugenioDerbez', 'EvaLongoria', 'FabioPorchat', 'Fabio_Coentrao',
#        'facufacundo', 'FALCAO', 'FannyLu', 'farisf9', 'FarOutAkhtar',
#        'FatinSL', 'fayez_malki', 'Fearnecotton', 'feliciaday',
#        'felipeneto', 'FePaesLeme', 'Fergie', 'FifthHarmony',
#        'FinallyMario', 'Fiuk', 'Flordelav', 'FLOTUS', 'FloydMayweather',
#        'Fonseca', 'FrancoDVita', 'FrencHMonTanA', 'gabyespino',
#        'gadelmaleh', 'gadiiing', 'galifianakisz', 'GalileaMontijo',
#        'GarethBale11', 'Garik2000', 'GaryBarlow', 'GaryLineker',
#        'GaryValenciano1', 'GemmaAnneStyles', 'geneliad', 'germanpaoloski',
#        'gio_antonelli', 'giseleofficial', 'gisel_la', 'gitagut',
#        'GiulianaRancic', 'GloriaTrevi', 'GNev2', 'GordonRamsay',
#        'GreenDay', 'greysonchance', 'Guaje7Villa', 'gulbenergen',
#        'gusttavo_lima', 'G_Higuain', 'haashoficial', 'Hadise',
#        'HaifaWehbe', 'HamzaNamira', 'handeyener', 'HARDWELL', 'hardwick',
#        'Harry_Styles', 'HayesGrier', 'hazardeden10', 'HeffronDrive',
#        'heidiklum', 'henrygayle', 'henrylau89', 'HilaryDuff',
#        'hitRECordJoe', 'hollywills', 'hulyavsar', 'iamjamiefoxx',
#        'IAmJericho', 'IAMJHUD', 'IAMQUEENLATIFAH', 'iamsrk',
#        'IAmSteveHarvey', 'iamsuperbianca', 'iamwill', 'IanMcKellen',
#        'iansomerhalder', 'IBGDRGN', 'Ibra_official', 'icecube',
#        'IGGYAZALEA', 'iHrithik', 'ilovegeorgina', 'iloveruffag',
#        'Imaginedragons', 'imdanielpadilla', 'ImRaina', 'ImRo45',
#        'imVkohli', 'ImZaheer', 'INDONESIAinLOVE', 'indrabektiasli',
#        'iqbaale', 'IrfanBachdim10', 'isco_alarcon', 'itsenriquegil',
#        'itsgabrielleu', 'ivetesangalo', 'iyavillania', 'jack',
#        'jackgilinsky', 'JackHarries', 'jackwhitehall', 'jackybrv',
#        'jaimecamil', 'JakeTAustin', 'JAlvarezFlow', 'jamesdrodriguez',
#        'jamesmaslow', 'JanetJackson', 'jasonderulo', 'jasonsegel',
#        'Jason_Aldean', 'jason_mraz', 'Javier_Alatorre', 'JBALVIN',
#        'jccaylen', 'JColeNC', 'jennettemccurdy', 'JENNIWOWW',
#        'JeremyBieber', 'JeremyClarkson', 'jeremypiven', 'JerrySeinfeld',
#        'jesseyjoy', 'jessicaalba', 'jessicacediel', 'JessicaSimpson',
#        'JessieJ', 'JHarden13', 'jhongsample', 'jhutch1992', 'JimCarrey',
#        'JimGaffigan', 'jimjonescapo', 'jimmycarr', 'jimmyeatworld',
#        'jimmyfallon', 'jimmykimmel', 'JKCorden', 'jk_rowling', 'JLo',
#        'JodiStaMaria', 'joejonas', 'joelmchale', 'JoelOsteen',
#        'Joey7Barton', 'JoeyEssex_', 'JoeyGraceffa', 'Joe_Sugg',
#        'JohnBishop100', 'JohnCena', 'JohnCleese', 'johngreen',
#        'johnlegend', 'JordinSparks', 'jorgeemateus', 'JoshDevineDrums',
#        'jotaquest', 'JoyceMeyer', 'jtimberlake', 'juanes',
#        'JuanLuisGuerra', 'juanmata8', 'juliaperrez', 'julietav',
#        'juniorbachchan', 'jupaesoficial', 'justdemi', 'justinbieber',
#        'KadimAlSahirORG', 'KAKA', 'kanyewest', 'KapilSharmaK9',
#        'karanjohar', 'kasimf', 'katedelcastillo', 'KatGraham',
#        'KattPackAllDay', 'katyperry', 'kc_concepcion', 'KDTrey5',
#        'KeithUrban', 'KellyOsbourne', 'KELLYROWLAND', 'kenandogulu',
#        'KendallJenner', 'KendraWilkinson', 'kendricklamar', 'KeriHilson',
#        'kerrywashington', 'KeshaRose', 'kevadamsss', 'KevinHart4real',
#        'kevinjonas', 'KevinSpacey', 'khloekardashian', 'Khunnie0624',
#        'KimKardashian', 'KingJames', 'kingsthings', 'kobebryant',
#        'kojiharunyan', 'kourtneykardash', 'KP24', 'KrisJenner',
#        'krungy21', 'kuyakim_atienza', 'KylieJenner', 'kylieminogue',
#        'KyrieIrving', 'k_alshenaif', 'LAAZCARATE', 'ladygaga',
#        'lafouine78', 'lala', 'lancearmstrong', 'LaraDutta', 'LAURAGII',
#        'LaurenConrad', 'LeighFrancis', 'lenadunham', 'LennyKravitz',
#        'LeoDiCaprio', 'LeventUzumcu', 'LewisHamilton', 'LilTunechi',
#        'lindsaylohan', 'linkinpark', 'LisaSurihani', 'LittleMix',
#        'LizGillies', 'llcoolj', 'LMFAO', 'lopezandres', 'lopezdoriga',
#        'Lord_Sugar', 'lorenzojova', 'lottietommo', 'Louis_Tomlinson',
#        'luansantana', 'LuceroMexico', 'LucianoHuck', 'luckymanzano',
#        'lucyhale', 'Ludacris', 'LuisChataing', 'LuisFonsi', 'luisnani',
#        'LuisSuarez9', 'Luke5SOS', 'LukeBryanOnline', 'luke_brooks',
#        'lulopilato', 'LunaMaya26', 'macklemore', 'MacMiller', 'maddow',
#        'MadhuriDixit', 'MagicJohnson', 'MaiteOficial', 'manaoficial',
#        'mangeshkarlata', 'manomenezes', 'Manuel_Neuer', 'manugavassi',
#        'manuginobili', 'MarcAnthony', 'MarceloM12', 'MarceloTas',
#        'marcoluque', 'marcosmion', 'MarcusButler', 'mariagadu',
#        'MariahCarey', 'mariashriver', 'mariko_dayo', 'MarioGoetze',
#        'markhoppus', 'MarkWright_', 'marley_ok', 'maroon5',
#        'MarthaStewart', 'MartinGarrix', 'maryjblige', 'masason',
#        'Mascherano', 'matsu_bouzu', 'MCHammer', 'McIlroyRory', 'mcuban',
#        'MeekMill', 'Metallica', 'mh_awadi', 'Michael5SOS', 'michaelbuble',
#        'MichelleObama', 'micheltelo', 'michkeegan', 'MikaSingh',
#        'MikeTyson', 'MileyCyrus', 'mindykaling', 'MirandaCosgrove',
#        'MirandaKerr', 'mirandalambert', 'MirzaSania', 'mishari_alafasy',
#        'MissyElliott', 'mnzadornov', 'MoezMasoud', 'MohamadAlarefe',
#        'MonsieurDream', 'montanertwiter', 'MrJamesMay', 'MrPeterAndre',
#        'mrsayudewi', 'MrsSOsbourne', 'msdhoni', 'MsLeaSalonga',
#        'MuratBoz', 'mustafaceceli', 'MustafaHosny', 'mustafa_agha',
#        'myfabolouslife', 'mynameisrossa', 'najwakaram', 'NajwaShihab',
#        'NancyAjram', 'Nashgrier', 'NathanFillion', 'NathanKress',
#        'neilhimself', 'neiltyson', 'NellyFurtado', 'Nelly_Mo', 'neymarjr',
#        'NeYoCompound', 'NiallOfficial', 'NickCannon', 'NICKIMINAJ',
#        'nickjonas', 'nicolerichie', 'NicoleScherzy', 'nikkigil',
#        'Niltakipte', 'ninadobrev', 'ninagarcia', 'noaheverett', 'NOAH_ID',
#        'NoelSchajris', 'NormanDesVideos', 'notch', 'nxzerooficial',
#        'ochocinco', 'officialJKT48', 'officialpepe', 'officialtulisa',
#        'OfficialWillow', 'official_flo', 'OficialGio', 'okanbayulgen',
#        'OlaAlfares', 'olla_ramlan', 'OMARCHAPARRO', 'Omar_Almulhem',
#        'omeshomesh', 'onedirection', 'OneRepublic', 'Oprah', 'oscar8',
#        'OscarDLeon', 'OscarFilho', 'oserginho', 'OzzyOsbourne',
#        'pabloalboran', 'pamyurin', 'paramore', 'ParineetiChopra',
#        'ParisHilton', 'pattiemallette', 'pattonoswalt', 'paugasol',
#        'PaulaAbdul', 'PaulaFernandes7', 'paulitachaves', 'PaulMcCartney',
#        'paulocoelho', 'paulpierce34', 'paulwesley', 'PBiaL', 'PearlJam',
#        'pedroalfonsoo', 'PerezHilton', 'Persie_Official', 'Pharrell',
#        'piersmorgan', 'Pink', 'pitbull', 'PochoLavezzi', 'Poconggg',
#        'Podolski10', 'polo_polo', 'prattprattpratt', 'PretaGil',
#        'PrinceRoyce', 'PrincesSyahrini', 'priyankachopra', 'psy_oppa',
#        'QueenRania', 'questlove', 'RachelZoe', 'radioleary',
#        'radityadika', 'RafaelNadal', 'RaffiAhmadLagi', 'rafinhabastos',
#        'raghebalama', 'rainnwilson', 'raisa6690', 'rampalarjun',
#        'RandyOrton', 'raphaelvarane', 'RealHughJackman', 'RealLamarOdom',
#        'RealPaulWalker', 'realpreityzinta', 'RealVolya', 'realwbonner',
#        'RebelWilson', 'ReggieBush', 'ReikMx', 'Residente', 'RevRunWisdom',
#        'rialjorge', 'Ricardo_Arjona', 'richardbranson', 'RichardHammond',
#        'rickygervais', 'ricky_martin', 'rihanna', 'rioferdy5',
#        'ristomejide', 'RitaOra', 'Riteishd', 'RNTata2000',
#        'robbiewilliams', 'robdyrdek', 'RobertDowneyJr', 'robertmarion',
#        'RobertsEmma', 'robkardashian', 'rodrigovesgo', 'rogerfederer',
#        'RolaWorLD', 'RomeoSantosPage', 'russwest44', 'rustyrockets',
#        'RyanSeacrest', 'RyanSheckler', 'SabrinaSatoReal', 'sachin_rt',
#        'SalehAlmoghamsy', 'salman_alodah', 'SamiAlJaber', 'SamNasri19',
#        'SamuelLJackson', 'samuelmilby', 'SandraDewi88', 'SandyLeah',
#        'SaraBareilles', 'SarahKSilverman', 'sardesairajdeep', 'sarseh',
#        'Schofe', 'Schwarzenegger', 'scooterbraun', 'ScottDisick',
#        'SeanKingston', 'sebastianrulli', 'sectorkekz', 'selenagomez',
#        'SeppBlatter', 'serenawilliams', 'SergioRamos', 'sertaberener',
#        'SethMacFarlane', 'sethmeyers', 'Sethrogen', 'sgokbakar',
#        'shahidkapoor', 'shakira', 'ShaneWarne', 'SHAQ', 'ShawnMendes',
#        'ShawnMichaels', 'shaymitch', 'shfly3424', 'shitmydadsays',
#        'showimah', 'ShraddhaKapoor', 'shreyaghoshal', 'shrutihaasan',
#        'shugairi', 'shymofficiel', 'silagencoglu', 'SimonCowell',
#        'simonpegg', 'SintoniaVerso', 'siyovushdustov', 'Skrillex',
#        'Slash', 'SleepintheGardn', 'smosh', 'smoshanthony',
#        'sneijder101010', 'snooki', 'SnoopDogg', 'SofiaVergara',
#        'solennheussaff', 'sonakshisinha', 'sonamakapoor', 'sonunigam',
#        'soujorge', 'souljaboy', 'special1004', 'SpiderAnderson',
#        'SrBachchan', 'SSantiagosegura', 'stephenasmith', 'StephenAtHome',
#        'StephenCurry30', 'stephenfry', 'steveaoki', 'steveaustinBSR',
#        'SteveCarell', 'SteveMartinToGo', 'SteveNash', 'Stromae',
#        'susoelpaspi', 'Su_Gimenez', 'syntekoficial', 'Talhabeeb',
#        'TareqAlSuwaidan', 'tarkan', 'Tatawerneck', 'taylorswift13',
#        'Tbambino', 'thalia', 'ThatKevinSmith', 'thebeatles',
#        'TheCarlosPena', 'TheEllenShow', 'TheFarahKhan', 'thekillers',
#        'thekiranbedi', 'TheMandyMoore', 'themichaelowen', 'TheRealAC3',
#        'therealjuicyj', 'TheRealMikeEpps', 'TheRock', 'TheShilpaShetty',
#        'TheVampsband', 'TheVijayMallya', 'theweeknd', 'Thiago6',
#        'thiaguinhocomth', 'ThisisDavina', 'tiesto', 'TigerWoods',
#        'TimTebow', 'Tip', 'Titi_KamaLL', 'TomCavalcante1', 'TomDaley1994',
#        'TomFelton', 'tomhanks', 'ToniKroos', 'tonyhawk', 'TonyRobbins',
#        'Torres', 'TravieMcCoy', 'Trevornoah', 'TreySongz', 'TripleH',
#        'troyesivan', 'TurkiAldakhil', 'twhiddleston', 'Tyga',
#        'tyleroakley', 'tylerperry', 'Tyrese', 'UncleRUSH', 'urgantcom',
#        'usainbolt', 'Usher', 'ValeYellow46', 'VanessaHudgens',
#        'vazqueznico', 'VeraBrezhneva', 'VhongX44', 'vicegandako',
#        'victoriabeckham', 'VictoriaJustice', 'vidialdiano',
#        'VigilanteArtist', 'VincentKompany', 'VINNYGUADAGNINO',
#        'virendersehwag', 'vjdaniel', 'Wale', 'waleedalfarraj',
#        'WayneRooney', 'williebosshog', 'williecolon', 'willylevy29',
#        'wilw', 'wisinyyandel', 'wizkhalifa', 'woodyinho', 'wossy',
#        'WWEDanielBryan', 'wyclef', 'XabiAlonso', 'XianLimm',
#        'xtianbautista', 'xtina', 'xuxameneghel', 'YALINonline',
#        'YASSER_Q_Y20', 'YengPLUGGEDin', 'yilmazerdogan', 'yokoono',
#        'YordiRosado', 'YosriFouda', 'Yusuf_Mansur', 'YUVSTRONG12',
#        'ZacEfron', 'zairana', 'zaynmalik', 'Zedd', 'Zendaya',
#        'zoetheband', 'ZooeyDeschanel', '_Pedro17_'], dtype=object)

# %%
final_df.to_csv("D:/Projects/Personal/Hackathon/TwinSpherev2/Data/CelebrityTweets.csv")

# %%
celebrity_tweets = pd.read_csv("D:/Projects/Personal/Hackathon/TwinSpherev2/Data/CelebrityTweets.csv")

# %%
celebrity_tweets.head()
# Out:
#    Unnamed: 0           twitter_id                       date  \
# 0           0  1265675160813780996  2020-05-27 16:04:08+00:00
# 1           1  1352116023261097987  2021-01-21 04:49:15+00:00
# 2           2  1305913958898053121  2020-09-15 16:58:45+00:00
# 3           3  1515766356548984835  2022-04-17 18:57:15+00:00
# 4           4  1166752233305886721  2019-08-28 16:39:44+00:00
#
#                                                tweet    name
# 0  b'RT @OSDONOSDABOLA: O Craque @10neto j\xc3\xa...  10neto
# 1  b'@plihalespn Vc t\xc3\xa1 certo \xf0\x9f\x97\...  10neto
# 2  b'Parab\xc3\xa9ns ao @Gremio pelos 117 anos de...  10neto
# 3  b'Inacredit\xc3\xa1vel o p\xc3\xaanalti que ma...  10neto
# 4  b'RT @OSDONOSDABOLA: A\xc3\xad galera, vamos v...  10neto

# %%
# Group by name and sample + concatenate
grouped = (
    celebrity_tweets.groupby("name")["tweet"]
    .apply(lambda x: "<ENDOFTWEET>".join(x.sample(n=min(100, len(x)), random_state=42)))
    .reset_index(name="concatenated_tweets")
)

# %%
grouped.head()
# Out:
#               name                                concatenated_tweets
# 0     10Ronaldinho  b'Baita recep\xc3\xa7\xc3\xa3o dessa galera an...
# 1           10neto  b'@andreolifelipe A\xc3\xad brigam com a gente...
# 2      143redangel  b'Julie Yap-Daza = huli (To get caught). \n\ne...
# 3  1LoganHenderson  b"Check this out! @LOWDNoizez' debut single of...
# 4    1victorvaldes  b'\xd8\xb4\xd8\xb1\xd9\x83\xd8\xa9 \xd8\xa7\xd...

# %%
# Save to a new CSV (optional)
grouped.to_csv("grouped_concatenated_tweets.csv", index=False)
